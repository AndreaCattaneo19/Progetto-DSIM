# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaCattaneo19/Progetto-DSIM/blob/main/LSTM%26GRU_Time_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Librerie

# %%
from tensorflow import random
random.set_seed(123)

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import plotly.express as px

from sklearn.metrics import mean_absolute_percentage_error as mape

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import LeakyReLU
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import GRU

# %% [markdown]
# #Modello LSTM (Long Short Term Memory)

# %% [markdown]
# ### Import e preparazione dei dati

# %%
df=pd.read_csv('/content/drive/MyDrive/PROGETTO_SDMTS_CONSEGNA/Codice_parte_ML/No_null_project_data.csv')

# %%
df.head()
# Out:
#          Date  Hour    CO                 Time
# 0  2004-03-10    18  1360  2004-03-10 18:00:00
# 1  2004-03-10    19  1292  2004-03-10 19:00:00
# 2  2004-03-10    20  1402  2004-03-10 20:00:00
# 3  2004-03-10    21  1376  2004-03-10 21:00:00
# 4  2004-03-10    22  1272  2004-03-10 22:00:00

# %%
#df.dtypes

# %%
#Ricostruisco variabile Time perchè non sembra possibile evitare che pd.to_datetime inserisca il salto del cambio d'ora
df['Time'] = pd.to_datetime(df['Date']) + pd.to_timedelta(df['Hour'], 'h')

# %%
#Cancello colonne non più necessarie
df.drop(['Date', 'Hour'], axis='columns', inplace=True)

# %%
df.dtypes
# Out:
# CO               int64
# Time    datetime64[ns]
# dtype: object

# %%
#df.head()

# %%
#Controllo la presenza di nulli
df.isnull().sum()
# Out:
# CO      0
# Time    0
# dtype: int64

# %%
#Setto la data come indice
df.set_index('Time', inplace=True)

# %%
df.head()
# Out:
#                        CO
# Time
# 2004-03-10 18:00:00  1360
# 2004-03-10 19:00:00  1292
# 2004-03-10 20:00:00  1402
# 2004-03-10 21:00:00  1376
# 2004-03-10 22:00:00  1272

# %%
#Il dataset viene convertito in una struttura più adatta ad essere gestita da una rete neurale: un numpy array di tipo float
data=df
data=data.values
data=data.astype('float32')
data
# Out:
# array([[1360.],
#        [1292.],
#        [1402.],
#        ...,
#        [ 827.],
#        [ 776.],
#        [ 755.]], dtype=float32)

# %%
type(data)
# Out:
# numpy.ndarray

# %%
#Poiché i modelli LSTM sono sensibili alla scala dell'input i dati vengono normalizzati
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(data)

#si creano train e test set (stesso split 80-20 usato per Arima e UCM)
train, test = dataset[0:6821,:], dataset[6821:len(dataset), :]

# %%
print(train)
# Out:
# [[0.511845  ]
#  [0.4630294 ]
#  [0.54199576]
#  ...
#  [0.50681984]
#  [0.43575016]
#  [0.3890883 ]]

# %%
print(test)
# Out:
# [[0.38478103]
#  [0.3862168 ]
#  [0.32376167]
#  ...
#  [0.12921754]
#  [0.09260592]
#  [0.07753053]]

# %% [markdown]
# A questo punto è necessario strutturare i dati in una forma che divida le osservazioni di training set e test set in X e Y. Dove con X si indicano i valori da utilizzare per prevere il valore successivo Y.
# Questa struttura è espressamente richiesta dalla rete. La quantità di osservazioni necessarie a prevedere la successiva sarà definita dal parametro lookback.
# In questo caso data la presenza di una stagionalità giornaliera e settimanale sui dati orari si è scelto di settare lookback a 168=24*7 (che comprende anche la stagionalità giornaliera)

# %%
def X_Y_split(dataset, look_back):
  X, Y = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    X.append(a)
    Y.append(dataset[i + look_back, 0])
  return np.array(X), np.array(Y)

# %%
look_back=168

# %%
TrainX, TrainY = X_Y_split(train, look_back)

# %%
#Composto di n vettori, ciascuno dei quali contiene 168 osservazioni con cui prevedere la relativa Y
TrainX
# Out:
# array([[0.511845  , 0.4630294 , 0.54199576, ..., 0.40201005, 0.51543427,
#         0.43072507],
#        [0.4630294 , 0.54199576, 0.5233309 , ..., 0.51543427, 0.43072507,
#         0.6532663 ],
#        [0.54199576, 0.5233309 , 0.4486719 , ..., 0.43072507, 0.6532663 ,
#         0.9519024 ],
#        ...,
#        [0.50610197, 0.42211053, 0.34458002, ..., 0.40918878, 0.46733668,
#         0.48815504],
#        [0.42211053, 0.34458002, 0.30581477, ..., 0.46733668, 0.48815504,
#         0.4637473 ],
#        [0.34458002, 0.30581477, 0.30653265, ..., 0.48815504, 0.4637473 ,
#         0.50681984]], dtype=float32)

# %%
#Train Y sarà composto di tante osservazioni quanti sono i vettori di TrainX
TrainY
# Out:
# array([0.6532663 , 0.9519024 , 0.95333815, ..., 0.4637473 , 0.50681984,
#        0.43575016], dtype=float32)

# %%
TrainX.shape
# Out:
# (6652, 168)

# %%
TrainY.shape
# Out:
# (6652,)

# %%
TestX, TestY = X_Y_split(test, look_back)

# %% [markdown]
# La rete LSTM prevede che i dati di input (X) siano forniti con una struttura matriciale specifica sotto forma di: [campione, step temporale, features]. Poichè vogliamo prevedere una singola osservazione con ciascun campione (prevediamo solo l'osservazione immediatamente successiva), lo step sarà pari ad 1. Mentre campione e features saranno righe e colonne di TrainX e TestX. Si trasformano dunque Xtrain e Xtest nella forma richiesta dal modello per fare le previsioni.

# %%
TrainX = np.reshape(TrainX, (TrainX.shape[0], 1, TrainX.shape[1]))
TestX = np.reshape(TestX, (TestX.shape[0], 1, TestX.shape[1]))

# %% [markdown]
# ##Creazione del modello LSTM

# %% [markdown]
# ### 1 layer LSTM 128 e dropout con 0.5 optimizer Adagrad

# %%
early_stop=EarlyStopping(monitor='loss',
                         patience=5)

# %%
model=Sequential()
model.add(LSTM(128, input_shape=(1, look_back)))
model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error',  # funzione di errore che dovrà essere minimizzata in fase di training
              optimizer='Adagrad')

# %%
model.fit(TrainX, TrainY, epochs=100, batch_size=32, verbose=2, callbacks = [early_stop], shuffle=False)
# Out:
# Epoch 1/100
# 208/208 - 11s - loss: 0.0555 - 11s/epoch - 51ms/step
# Epoch 2/100
# 208/208 - 1s - loss: 0.0285 - 1s/epoch - 6ms/step
# Epoch 3/100
# 208/208 - 2s - loss: 0.0257 - 2s/epoch - 7ms/step
# Epoch 4/100
# 208/208 - 1s - loss: 0.0254 - 1s/epoch - 7ms/step
# Epoch 5/100
# 208/208 - 1s - loss: 0.0237 - 1s/epoch - 7ms/step
# Epoch 6/100
# 208/208 - 1s - loss: 0.0234 - 1s/epoch - 7ms/step
# Epoch 7/100
# 208/208 - 2s - loss: 0.0232 - 2s/epoch - 8ms/step
# Epoch 8/100
# 208/208 - 1s - loss: 0.0222 - 1s/epoch - 7ms/step
# Epoch 9/100
# 208/208 - 1s - loss: 0.0214 - 937ms/epoch - 5ms/step
# Epoch 10/100
# 208/208 - 1s - loss: 0.0210 - 938ms/epoch - 5ms/step
# Epoch 11/100
# 208/208 - 1s - loss: 0.0203 - 780ms/epoch - 4ms/step
# Epoch 12/100
# 208/208 - 1s - loss: 0.0198 - 653ms/epoch - 3ms/step
# Epoch 13/100
# 208/208 - 1s - loss: 0.0194 - 670ms/epoch - 3ms/step
# Epoch 14/100
# 208/208 - 1s - loss: 0.0189 - 663ms/epoch - 3ms/step
# Epoch 15/100
# 208/208 - 1s - loss: 0.0191 - 661ms/epoch - 3ms/step
# Epoch 16/100
# 208/208 - 1s - loss: 0.0181 - 668ms/epoch - 3ms/step
# Epoch 17/100
# 208/208 - 1s - loss: 0.0180 - 661ms/epoch - 3ms/step
# Epoch 18/100
# 208/208 - 1s - loss: 0.0176 - 656ms/epoch - 3ms/step
# Epoch 19/100
# 208/208 - 1s - loss: 0.0172 - 675ms/epoch - 3ms/step
# Epoch 20/100
# 208/208 - 1s - loss: 0.0170 - 663ms/epoch - 3ms/step
# Epoch 21/100
# 208/208 - 1s - loss: 0.0170 - 781ms/epoch - 4ms/step
# Epoch 22/100
# 208/208 - 1s - loss: 0.0166 - 882ms/epoch - 4ms/step
# Epoch 23/100
# 208/208 - 1s - loss: 0.0166 - 880ms/epoch - 4ms/step
# Epoch 24/100
# 208/208 - 1s - loss: 0.0162 - 876ms/epoch - 4ms/step
# Epoch 25/100
# 208/208 - 1s - loss: 0.0160 - 903ms/epoch - 4ms/step
# Epoch 26/100
# 208/208 - 1s - loss: 0.0158 - 888ms/epoch - 4ms/step
# Epoch 27/100
# 208/208 - 1s - loss: 0.0154 - 885ms/epoch - 4ms/step
# Epoch 28/100
# 208/208 - 1s - loss: 0.0152 - 673ms/epoch - 3ms/step
# Epoch 29/100
# 208/208 - 1s - loss: 0.0155 - 664ms/epoch - 3ms/step
# Epoch 30/100
# 208/208 - 1s - loss: 0.0153 - 651ms/epoch - 3ms/step
# Epoch 31/100
# 208/208 - 1s - loss: 0.0146 - 664ms/epoch - 3ms/step
# Epoch 32/100
# 208/208 - 1s - loss: 0.0145 - 654ms/epoch - 3ms/step
# Epoch 33/100
# 208/208 - 1s - loss: 0.0148 - 661ms/epoch - 3ms/step
# Epoch 34/100
# 208/208 - 1s - loss: 0.0145 - 676ms/epoch - 3ms/step
# Epoch 35/100
# 208/208 - 1s - loss: 0.0142 - 655ms/epoch - 3ms/step
# Epoch 36/100
# 208/208 - 1s - loss: 0.0142 - 660ms/epoch - 3ms/step
# Epoch 37/100
# 208/208 - 1s - loss: 0.0144 - 654ms/epoch - 3ms/step
# Epoch 38/100
# 208/208 - 1s - loss: 0.0139 - 659ms/epoch - 3ms/step
# Epoch 39/100
# 208/208 - 1s - loss: 0.0136 - 650ms/epoch - 3ms/step
# Epoch 40/100
# 208/208 - 1s - loss: 0.0138 - 666ms/epoch - 3ms/step
# Epoch 41/100
# 208/208 - 1s - loss: 0.0136 - 674ms/epoch - 3ms/step
# Epoch 42/100
# 208/208 - 1s - loss: 0.0133 - 700ms/epoch - 3ms/step
# Epoch 43/100
# 208/208 - 1s - loss: 0.0134 - 872ms/epoch - 4ms/step
# Epoch 44/100
# 208/208 - 1s - loss: 0.0134 - 874ms/epoch - 4ms/step
# Epoch 45/100
# 208/208 - 1s - loss: 0.0134 - 883ms/epoch - 4ms/step
# Epoch 46/100
# 208/208 - 1s - loss: 0.0133 - 878ms/epoch - 4ms/step
# Epoch 47/100
# 208/208 - 1s - loss: 0.0133 - 878ms/epoch - 4ms/step
# Epoch 48/100
# 208/208 - 1s - loss: 0.0131 - 935ms/epoch - 4ms/step
# Epoch 49/100
# 208/208 - 1s - loss: 0.0128 - 747ms/epoch - 4ms/step
# Epoch 50/100
# 208/208 - 1s - loss: 0.0131 - 703ms/epoch - 3ms/step
# Epoch 51/100
# 208/208 - 1s - loss: 0.0126 - 688ms/epoch - 3ms/step
# Epoch 52/100
# 208/208 - 1s - loss: 0.0128 - 661ms/epoch - 3ms/step
# Epoch 53/100
# 208/208 - 1s - loss: 0.0128 - 687ms/epoch - 3ms/step
# Epoch 54/100
# 208/208 - 1s - loss: 0.0124 - 691ms/epoch - 3ms/step
# Epoch 55/100
# 208/208 - 1s - loss: 0.0125 - 672ms/epoch - 3ms/step
# Epoch 56/100
# 208/208 - 1s - loss: 0.0123 - 661ms/epoch - 3ms/step
# Epoch 57/100
# 208/208 - 1s - loss: 0.0124 - 668ms/epoch - 3ms/step
# Epoch 58/100
# 208/208 - 1s - loss: 0.0124 - 660ms/epoch - 3ms/step
# Epoch 59/100
# 208/208 - 1s - loss: 0.0123 - 667ms/epoch - 3ms/step
# Epoch 60/100
# 208/208 - 1s - loss: 0.0121 - 648ms/epoch - 3ms/step
# Epoch 61/100
# 208/208 - 1s - loss: 0.0123 - 681ms/epoch - 3ms/step
# Epoch 62/100
# 208/208 - 1s - loss: 0.0118 - 819ms/epoch - 4ms/step
# Epoch 63/100
# 208/208 - 1s - loss: 0.0121 - 973ms/epoch - 5ms/step
# Epoch 64/100
# 208/208 - 1s - loss: 0.0117 - 967ms/epoch - 5ms/step
# Epoch 65/100
# 208/208 - 1s - loss: 0.0118 - 1s/epoch - 5ms/step
# Epoch 66/100
# 208/208 - 1s - loss: 0.0118 - 949ms/epoch - 5ms/step
# Epoch 67/100
# 208/208 - 1s - loss: 0.0118 - 951ms/epoch - 5ms/step
# Epoch 68/100
# 208/208 - 1s - loss: 0.0119 - 907ms/epoch - 4ms/step
# Epoch 69/100
# 208/208 - 1s - loss: 0.0117 - 902ms/epoch - 4ms/step

# %% [markdown]
# ### Previsione del test e valutazione modello

# %%
#Previsioni
pred_mod1_train = model.predict(TrainX)
pred_mod1_test = model.predict(TestX)
# Out:
# 208/208 [==============================] - 1s 2ms/step
# 48/48 [==============================] - 0s 2ms/step

# %%
#Per valutare bontà di previsioni le riscalo e le confronto con i dati originali riscalati
#Train
rescaled_pred_train = scaler.inverse_transform(pred_mod1_train)
rescaled_train_y = scaler.inverse_transform([TrainY])
#Test
rescaled_pred_test = scaler.inverse_transform(pred_mod1_test)
rescaled_test_y = scaler.inverse_transform([TestY])

# %%
#MAPE train
MAPE_train=mape(rescaled_train_y[0], rescaled_pred_train[:,0])
MAPE_train
# Out:
# 0.09131950015525138

# %%
#MAPE test
MAPE_test=mape(rescaled_test_y[0], rescaled_pred_test[:,0])
MAPE_test
# Out:
# 0.10158705912961703

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(rescaled_pred_train)+look_back, :] = rescaled_pred_train
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(rescaled_pred_train)+(look_back*2)+1:len(dataset)-1, :] = rescaled_pred_test
# plot baseline and predictions
figure(figsize=(20, 8), dpi=80)
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
#Previsti contro effettivi
figure(figsize=(20, 8), dpi=80)
plt.plot(rescaled_test_y[0], label='True')
plt.plot(rescaled_pred_test[:,0], label='Predicted')
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### 1 layer LSTM 128 e dropout con 0.5, altro layer LSTM 64 e dropout 0.5 optimizer Adagrad

# %%
model2=Sequential()
model2.add(LSTM(128, input_shape=(1, look_back), return_sequences=True))
model2.add(LeakyReLU())
model2.add(Dropout(0.3))
model2.add(LSTM(64, return_sequences=False))
model2.add(LeakyReLU())
model2.add(Dropout(0.2))
model2.add(Dense(1))

# %%
model2.compile(loss='mean_squared_error',  # funzione di errore che dovrà essere minimizzata in fase di training
              optimizer='Adagrad')

# %%
model2.fit(TrainX, TrainY, epochs=100, batch_size=32, verbose=2, callbacks = [early_stop], shuffle=False)
# Out:
# Epoch 1/100
# 208/208 - 4s - loss: 0.1054 - 4s/epoch - 19ms/step
# Epoch 2/100
# 208/208 - 1s - loss: 0.0845 - 1s/epoch - 6ms/step
# Epoch 3/100
# 208/208 - 1s - loss: 0.0707 - 1s/epoch - 6ms/step
# Epoch 4/100
# 208/208 - 1s - loss: 0.0601 - 1s/epoch - 6ms/step
# Epoch 5/100
# 208/208 - 1s - loss: 0.0515 - 1s/epoch - 6ms/step
# Epoch 6/100
# 208/208 - 1s - loss: 0.0447 - 1s/epoch - 6ms/step
# Epoch 7/100
# 208/208 - 1s - loss: 0.0397 - 907ms/epoch - 4ms/step
# Epoch 8/100
# 208/208 - 1s - loss: 0.0354 - 915ms/epoch - 4ms/step
# Epoch 9/100
# 208/208 - 1s - loss: 0.0320 - 892ms/epoch - 4ms/step
# Epoch 10/100
# 208/208 - 1s - loss: 0.0298 - 911ms/epoch - 4ms/step
# Epoch 11/100
# 208/208 - 1s - loss: 0.0281 - 900ms/epoch - 4ms/step
# Epoch 12/100
# 208/208 - 1s - loss: 0.0268 - 896ms/epoch - 4ms/step
# Epoch 13/100
# 208/208 - 1s - loss: 0.0258 - 904ms/epoch - 4ms/step
# Epoch 14/100
# 208/208 - 1s - loss: 0.0251 - 900ms/epoch - 4ms/step
# Epoch 15/100
# 208/208 - 1s - loss: 0.0245 - 1s/epoch - 5ms/step
# Epoch 16/100
# 208/208 - 1s - loss: 0.0240 - 1s/epoch - 6ms/step
# Epoch 17/100
# 208/208 - 1s - loss: 0.0239 - 1s/epoch - 7ms/step
# Epoch 18/100
# 208/208 - 2s - loss: 0.0237 - 2s/epoch - 10ms/step
# Epoch 19/100
# 208/208 - 1s - loss: 0.0233 - 1s/epoch - 6ms/step
# Epoch 20/100
# 208/208 - 1s - loss: 0.0233 - 1s/epoch - 6ms/step
# Epoch 21/100
# 208/208 - 1s - loss: 0.0233 - 1s/epoch - 6ms/step
# Epoch 22/100
# 208/208 - 1s - loss: 0.0232 - 972ms/epoch - 5ms/step
# Epoch 23/100
# 208/208 - 1s - loss: 0.0232 - 931ms/epoch - 4ms/step
# Epoch 24/100
# 208/208 - 1s - loss: 0.0231 - 901ms/epoch - 4ms/step
# Epoch 25/100
# 208/208 - 1s - loss: 0.0230 - 900ms/epoch - 4ms/step
# Epoch 26/100
# 208/208 - 1s - loss: 0.0228 - 899ms/epoch - 4ms/step
# Epoch 27/100
# 208/208 - 1s - loss: 0.0229 - 886ms/epoch - 4ms/step
# Epoch 28/100
# 208/208 - 1s - loss: 0.0231 - 877ms/epoch - 4ms/step
# Epoch 29/100
# 208/208 - 1s - loss: 0.0228 - 881ms/epoch - 4ms/step
# Epoch 30/100
# 208/208 - 1s - loss: 0.0228 - 1s/epoch - 6ms/step
# Epoch 31/100
# 208/208 - 1s - loss: 0.0228 - 1s/epoch - 6ms/step
# Epoch 32/100
# 208/208 - 1s - loss: 0.0228 - 1s/epoch - 7ms/step
# Epoch 33/100
# 208/208 - 2s - loss: 0.0227 - 2s/epoch - 7ms/step
# Epoch 34/100
# 208/208 - 1s - loss: 0.0226 - 1s/epoch - 7ms/step
# Epoch 35/100
# 208/208 - 2s - loss: 0.0227 - 2s/epoch - 7ms/step
# Epoch 36/100
# 208/208 - 1s - loss: 0.0227 - 1s/epoch - 7ms/step
# Epoch 37/100
# 208/208 - 2s - loss: 0.0225 - 2s/epoch - 7ms/step
# Epoch 38/100
# 208/208 - 2s - loss: 0.0227 - 2s/epoch - 7ms/step
# Epoch 39/100
# 208/208 - 1s - loss: 0.0222 - 1s/epoch - 7ms/step
# Epoch 40/100
# 208/208 - 1s - loss: 0.0223 - 1s/epoch - 6ms/step
# Epoch 41/100
# 208/208 - 1s - loss: 0.0225 - 1s/epoch - 6ms/step
# Epoch 42/100
# 208/208 - 1s - loss: 0.0221 - 905ms/epoch - 4ms/step
# Epoch 43/100
# 208/208 - 1s - loss: 0.0223 - 900ms/epoch - 4ms/step
# Epoch 44/100
# 208/208 - 1s - loss: 0.0225 - 946ms/epoch - 5ms/step
# Epoch 45/100
# 208/208 - 1s - loss: 0.0223 - 896ms/epoch - 4ms/step
# Epoch 46/100
# 208/208 - 1s - loss: 0.0224 - 908ms/epoch - 4ms/step
# Epoch 47/100
# 208/208 - 1s - loss: 0.0224 - 1s/epoch - 6ms/step

# %% [markdown]
# ### Previsione del test e valutazione modello

# %%
#Previsioni
pred_mod2_train = model2.predict(TrainX)
pred_mod2_test = model2.predict(TestX)
# Out:
# 208/208 [==============================] - 1s 2ms/step
# 48/48 [==============================] - 0s 3ms/step

# %%
#Per valutare bontà di previsioni le riscalo e le confronto con i dati originali riscalati
#Train
rescaled_pred_train2 = scaler.inverse_transform(pred_mod2_train)
rescaled_train_y2 = scaler.inverse_transform([TrainY])
#Test
rescaled_pred_test2 = scaler.inverse_transform(pred_mod2_test)
rescaled_test_y2 = scaler.inverse_transform([TestY])

# %%
#MAPE train
MAPE_train2=mape(rescaled_train_y2[0], rescaled_pred_train2[:,0])
MAPE_train2
# Out:
# 0.149074431817556

# %%
#MAPE test
MAPE_test2=mape(rescaled_test_y2[0], rescaled_pred_test2[:,0])
MAPE_test2
# Out:
# 0.15063091376131563

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(rescaled_pred_train2)+look_back, :] = rescaled_pred_train2
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(rescaled_pred_train2)+(look_back*2)+1:len(dataset)-1, :] = rescaled_pred_test2
# plot baseline and predictions
figure(figsize=(20, 8), dpi=80)
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
#Predetti contro effettivi
figure(figsize=(20, 8), dpi=80)
plt.plot(rescaled_test_y2[0], label='True')
plt.plot(rescaled_pred_test2[:,0], label='Predicted')
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# # Modello GRU

# %% [markdown]
# ## GRU

# %%
# reshape into X=t and Y=t+1
#look_back = 168
Xtrain, Ytrain = X_Y_split(train, look_back)
Xtest, Ytest = X_Y_split(test, look_back)

# %%
# reshape input to be [samples, time steps, features]
Xtrain = np.reshape(Xtrain, (Xtrain.shape[0], 1, Xtrain.shape[1]))
Xtest = np.reshape(Xtest, (Xtest.shape[0], 1, Xtest.shape[1]))

# %%
early_stop = EarlyStopping(monitor = 'loss', patience = 5)

# %%
model_GRU = Sequential()
model_GRU.add(GRU(128, input_shape=(1, look_back), return_sequences=True))
model_GRU.add(Dropout(0.5))
model_GRU.add(GRU(64, return_sequences=True))
model_GRU.add(GRU(32))
model_GRU.add(Dropout(0.5))
model_GRU.add(Dense(1))

# %%
model_GRU.compile(loss='mean_squared_error', optimizer='Adagrad')

# %%
model_GRU.fit(Xtrain, Ytrain, epochs=100, batch_size=32, verbose=1, callbacks = [early_stop])
# Out:
# Epoch 1/100
# 208/208 [==============================] - 7s 6ms/step - loss: 0.0603
# Epoch 2/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0317
# Epoch 3/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0301
# Epoch 4/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0294
# Epoch 5/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0286
# Epoch 6/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.0275
# Epoch 7/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0270
# Epoch 8/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0269
# Epoch 9/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0264
# Epoch 10/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0257
# Epoch 11/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0255
# Epoch 12/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.0256
# Epoch 13/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0242
# Epoch 14/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0240
# Epoch 15/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0241
# Epoch 16/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0239
# Epoch 17/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0234
# Epoch 18/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0229
# Epoch 19/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0231
# Epoch 20/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.0231
# Epoch 21/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.0225
# Epoch 22/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0224
# Epoch 23/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0214
# Epoch 24/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.0211
# Epoch 25/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0210
# Epoch 26/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0212
# Epoch 27/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0211
# Epoch 28/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0209
# Epoch 29/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0205
# Epoch 30/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0202
# Epoch 31/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0208
# Epoch 32/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.0201
# Epoch 33/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0194
# Epoch 34/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0193
# Epoch 35/100
# 208/208 [==============================] - 2s 9ms/step - loss: 0.0194
# Epoch 36/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0192
# Epoch 37/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.0190
# Epoch 38/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0188
# Epoch 39/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0188
# Epoch 40/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0185
# Epoch 41/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0187
# Epoch 42/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0183
# Epoch 43/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0181
# Epoch 44/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.0178
# Epoch 45/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.0183
# Epoch 46/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.0181
# Epoch 47/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0177
# Epoch 48/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0174
# Epoch 49/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0176
# Epoch 50/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0172
# Epoch 51/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0167
# Epoch 52/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0169
# Epoch 53/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0168
# Epoch 54/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0169
# Epoch 55/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0166
# Epoch 56/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.0165
# Epoch 57/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0164
# Epoch 58/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0165
# Epoch 59/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0161
# Epoch 60/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0162
# Epoch 61/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0162
# Epoch 62/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0158
# Epoch 63/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0161
# Epoch 64/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0158
# Epoch 65/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0158
# Epoch 66/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0156
# Epoch 67/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0151
# Epoch 68/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0158
# Epoch 69/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0152
# Epoch 70/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.0154
# Epoch 71/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.0152
# Epoch 72/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0151

# %% [markdown]
# ### Previsioni sul test e valutazione del modello

# %%
#Si fanno le previsioni
pred_train = model_GRU.predict(Xtrain)
pred_test = model_GRU.predict(Xtest)
# Out:
# 208/208 [==============================] - 1s 3ms/step
# 48/48 [==============================] - 0s 3ms/step

# %%
#Si riportano i dati nella forma originale  e si riscalano anche le previsioni
train_rescaled_Y3 = scaler.inverse_transform([Ytrain])
pred_train_rescaled_Y3 = scaler.inverse_transform(pred_train)

test_rescaled_Y3 = scaler.inverse_transform([Ytest])
pred_test_rescaled_Y3 = scaler.inverse_transform(pred_test)

# %%
#Valutazione performance predittive
GRU_train_MAPE = mape(train_rescaled_Y3[0], pred_train_rescaled_Y3[:,0])
GRU_train_MAPE
# Out:
# 0.09606188989179314

# %%
GRU_test_MAPE = mape(test_rescaled_Y3[0], pred_test_rescaled_Y3[:, 0])
GRU_test_MAPE
# Out:
# 0.10347771344762603

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(pred_train_rescaled_Y3)+look_back, :] = pred_train_rescaled_Y3
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(pred_train_rescaled_Y3)+(look_back*2)+1:len(dataset)-1, :] = pred_test_rescaled_Y3
# plot baseline and predictions
figure(figsize=(20, 8), dpi=80)
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
#Predetti contro effettivi
figure(figsize=(20, 8), dpi=80)
plt.plot(test_rescaled_Y3[0], label='True')
plt.plot(pred_test_rescaled_Y3[:,0], label='Predicted')
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## GRU 2

# %%
early_stop = EarlyStopping(monitor = 'loss', patience = 5)

# %%
model_GRU2 = Sequential()
model_GRU2.add(GRU(128, input_shape=(1, look_back), return_sequences=True))
model_GRU2.add(Dropout(0.5))
model_GRU2.add(GRU(64))
model_GRU2.add(Dropout(0.5))
model_GRU2.add(Dense(1))

# %%
model_GRU2.compile(loss='mean_squared_error', optimizer='Adagrad')

# %%
model_GRU2.fit(Xtrain, Ytrain, epochs=100, batch_size=32, verbose=1, callbacks = [early_stop])
# Out:
# Epoch 1/100
# 208/208 [==============================] - 4s 5ms/step - loss: 0.0564
# Epoch 2/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0388
# Epoch 3/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0370
# Epoch 4/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0340
# Epoch 5/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.0318
# Epoch 6/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0300
# Epoch 7/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0284
# Epoch 8/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0270
# Epoch 9/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0262
# Epoch 10/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0256
# Epoch 11/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0242
# Epoch 12/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0237
# Epoch 13/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0227
# Epoch 14/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0222
# Epoch 15/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0222
# Epoch 16/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0213
# Epoch 17/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0211
# Epoch 18/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0200
# Epoch 19/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0201
# Epoch 20/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.0195
# Epoch 21/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0194
# Epoch 22/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.0193
# Epoch 23/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.0184
# Epoch 24/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.0189
# Epoch 25/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0185
# Epoch 26/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0180
# Epoch 27/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0176
# Epoch 28/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0176
# Epoch 29/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0171
# Epoch 30/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0174
# Epoch 31/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0172
# Epoch 32/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0165
# Epoch 33/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0171
# Epoch 34/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0166
# Epoch 35/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0163
# Epoch 36/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0163
# Epoch 37/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0162
# Epoch 38/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0157
# Epoch 39/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0162
# Epoch 40/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0163
# Epoch 41/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0155
# Epoch 42/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0158
# Epoch 43/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0151
# Epoch 44/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0159
# Epoch 45/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0150
# Epoch 46/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0151
# Epoch 47/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0147
# Epoch 48/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0148
# Epoch 49/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0149
# Epoch 50/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.0143
# Epoch 51/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0149
# Epoch 52/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0142
# Epoch 53/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0146
# Epoch 54/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0148
# Epoch 55/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0144
# Epoch 56/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0145
# Epoch 57/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.0146

# %% [markdown]
# ### Previsioni sul test e valutazione del modello

# %%
#Si fanno le previsioni
pred_train_g2 = model_GRU2.predict(Xtrain)
pred_test_g2 = model_GRU2.predict(Xtest)
# Out:
# 208/208 [==============================] - 1s 2ms/step
# 48/48 [==============================] - 0s 2ms/step

# %%
#Si riportano i dati nella forma originale  e si riscalano anche le previsioni
train_rescaled_Y4 = scaler.inverse_transform([Ytrain])
pred_train_rescaled_Y4 = scaler.inverse_transform(pred_train_g2)

test_rescaled_Y4 = scaler.inverse_transform([Ytest])
pred_test_rescaled_Y4 = scaler.inverse_transform(pred_test_g2)

# %%
#Valutazione performance predittive
GRU2_train_MAPE = mape(train_rescaled_Y4[0], pred_train_rescaled_Y4[:,0])
GRU2_train_MAPE
# Out:
# 0.08630658968698278

# %%
GRU2_test_MAPE = mape(test_rescaled_Y4[0], pred_test_rescaled_Y4[:, 0])
GRU2_test_MAPE
# Out:
# 0.09228457176805842

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(pred_train_rescaled_Y4)+look_back, :] = pred_train_rescaled_Y4
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(pred_train_rescaled_Y4)+(look_back*2)+1:len(dataset)-1, :] = pred_test_rescaled_Y4
# plot baseline and predictions
figure(figsize=(20, 8), dpi=80)
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
#Predetti contro effettivi
figure(figsize=(20, 8), dpi=80)
plt.plot(test_rescaled_Y4[0], label='True')
plt.plot(pred_test_rescaled_Y4[:,0], label='Predicted')
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# # Confronto tra i modelli

# %%
MAPE_dict = {"LSTM1":round(MAPE_test, 4), "LSTM2":round(MAPE_test2, 4), "GRU1":round(GRU_test_MAPE, 4), "GRU2":round(GRU2_test_MAPE,4)}
models = list(MAPE_dict.keys())
performance = list(MAPE_dict.values())

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i], ha="center",
                 Bbox = dict(facecolor = 'white', alpha =.8))

# %%
fig = plt.figure(figsize=(14, 14))
plt.bar(models, performance, width=0.4)
plt.xlabel("Models trained")
plt.ylabel("MAPE")
plt.title("Models performance")
addlabels(models, performance)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-aa1a93f3efda> in <cell line: 6>()
#       4 plt.ylabel("MAPE")
#       5 plt.title("Models performance")
# ----> 6 addlabels(models, performance)
#       7 plt.show()
#
# <ipython-input-68-669d1cd173f1> in addlabels(x, y)
#       1 def addlabels(x,y):
#       2     for i in range(len(x)):
# ----> 3         plt.text(i,y[i],y[i], ha="center",
#       4                  Bbox = dict(facecolor = 'white', alpha =.8))
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in text(x, y, s, fontdict, **kwargs)
#    2983 @_copy_docstring_and_deprecators(Axes.text)
#    2984 def text(x, y, s, fontdict=None, **kwargs):
# -> 2985     return gca().text(x, y, s, fontdict=fontdict, **kwargs)
#    2986
#    2987
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in text(self, x, y, s, fontdict, **kwargs)
#     687             **kwargs,
#     688         }
# --> 689         t = mtext.Text(x, y, text=s, **effective_kwargs)
#     690         t.set_clip_path(self.patch)
#     691         self._add_text(t)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     452                 "parameter will become keyword-only %(removal)s.",
#     453                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454         return func(*args, **kwargs)
#     455
#     456     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, parse_math, **kwargs)
#     181             rotation_mode=rotation_mode,
#     182         )
# --> 183         self.update(kwargs)
#     184
#     185     def _reset_visual_defaults(
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/text.py in update(self, kwargs)
#     229         # Update bbox last, as it depends on font properties.
#     230         bbox = kwargs.pop("bbox", sentinel)
# --> 231         super().update(kwargs)
#     232         if bbox is not sentinel:
#     233             self.set_bbox(bbox)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in update(self, props)
#    1211         props : dict
#    1212         """
# -> 1213         return self._update_props(
#    1214             props, "{cls.__name__!r} object has no property {prop_name!r}")
#    1215
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1195                     func = getattr(self, f"set_{k}", None)
#    1196                     if not callable(func):
# -> 1197                         raise AttributeError(
#    1198                             errfmt.format(cls=type(self), prop_name=k))
#    1199                     ret.append(func(v))
#
# AttributeError: 'Text' object has no property 'Bbox'
